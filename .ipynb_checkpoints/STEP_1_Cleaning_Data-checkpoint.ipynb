# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
import math
import random

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
# df.head()

# %%
# df['id'].value_counts()

# %%
# df.loc[df['id']==795000620]

# %%
# df['bedrooms'].value_counts()

# %%
# df.loc[df['bedrooms']==33]

# %%
df['bedrooms'].replace(to_replace = 33, value =3 , inplace=True)

# %%
# df.loc[df['id']==2402100895]

# %%
# df['bathrooms'].value_counts()

# %%
pd.options.display.max_columns=100

# %%
# df.sort_values(by=['yr_built'],ascending=False)
# df['yr_built'].value_counts()
# df.loc[df['yr_built']==1900]

# %%
# df_test = df.duplicated(subset=None, keep='first')

# %%
# df_test.value_counts()

# %%
# df.isna().sum()

# %%
# df['waterfront'].unique()

# %%
# df['waterfront'].value_counts()

# %%
df['waterfront'].fillna(value=0,inplace=True)

# %%
# df['waterfront'].value_counts()

# %%
df['yr_renovated'].fillna(value=0,inplace=True)

# %%
# df.isna().sum()

# %%
df.dropna(subset=['view'],inplace=True)

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df['sqft_basement'].replace(to_replace = '?', value = df['sqft_living'] - df['sqft_above'], inplace=True)

# %%
# df['sqft_basement'].unique()

# %%
df['sqft_basement'] = df['sqft_basement'].astype("float32")

# %%
df1 = df.drop(columns=['date'])

# %%
plt.figure(figsize = (20,20))
sns.heatmap(df1.corr())

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import cross_validate, cross_val_predict, cross_val_score
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import BaggingRegressor

import gc; gc.enable()

import warnings
warnings.filterwarnings("ignore")

# %%
target = "price"
used_cols = [c for c in df1.columns.to_list() if c not in [target]]

X = df1[used_cols]
y = df1[target]

# %%
df.corr()[target].abs().sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701587
# grade            0.668307
# sqft_above       0.605695
# sqft_living15    0.585304
# bathrooms        0.525053
# view             0.395734
# sqft_basement    0.321816
# bedrooms         0.315229
# lat              0.307868
# waterfront       0.259220
# floors           0.257052
# yr_renovated     0.117982
# sqft_lot         0.090338
# sqft_lot15       0.083189
# yr_built         0.054273
# zipcode          0.053620
# condition        0.035393
# long             0.022417
# id               0.017392
# Name: price, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# results = pd.DataFrame({'Model': [],
#                            'Details':[],
#                            'Root Mean Squared Error (RMSE)':[],
#                            'R-squared (training)':[],
#                            'Adjusted R-squared (training)':[],
#                            'R-squared (test)':[],
#                            'Adjusted R-squared (test)':[],
#                            '3-Fold Cross Validation':[]})

# %%
scaler = RobustScaler()
lr = LinearRegression()
pipe1 = make_pipeline(scaler, lr)



def model_evaluate (pipe,df_new):
    
    features = [c for c in df_new.columns.to_list() if c not in ['price']]
    
    train_data , test_data = train_test_split(df_new,train_size = 0.8,random_state=3)

    lr.fit(train_data[features],train_data['price'])
    
    pred = lr.predict(test_data[features])
    
   
    rmsesm = float(format(np.sqrt(metrics.mean_squared_error(test_data['price'],pred)),'.3f'))
    rtrsm = float(format(lr.score(train_data[features],train_data['price']),'.3f'))
    rtesm = float(format(lr.score(test_data[features],test_data['price'] ),'.3f'))
    cv = float(format(cross_val_score(lr,df_new[features],df_new['price'],cv=3).mean(),'.3f'))
   
    print ("Average Price for Test Data: {:.3f}".format(test_data['price'].mean()))
    print('Intercept: {}'.format(lr.intercept_))
    print('Coefficient: {}'.format(lr.coef_))
    print(f'cv: {cv}')
    print(f'root mean square error: {rmsesm}')
    print(f'training R2: {rtrsm}')
    print(f'test R2: {rtesm}')
    
    return rmsesm,rtrsm,rtesm,cv

pipe1 = model_evaluate(pipe1,df1)
# Out:
# Average Price for Test Data: 540333.056
# Intercept: 4753417.743968099
# Coefficient: [-1.37733074e-06 -3.88048836e+04  4.28463302e+04  1.08818524e+02
#   1.38001346e-01  6.08126688e+03  6.09155388e+05  5.11071926e+04
#   2.68772426e+04  9.74136315e+04  7.09067817e+01  3.79117422e+01
#  -2.62504325e+03  2.80846820e+01 -5.73108355e+02  6.02212695e+05
#  -2.23412152e+05  2.27550213e+01 -4.09630879e-01]
# cv: 0.695
# root mean square error: 199548.645
# training R2: 0.699
# test R2: 0.706

# %%
scaler = RobustScaler()
lr =  Lasso(alpha=1000)
pipe2 = make_pipeline(scaler, lr)

pipe2 = model_evaluate(pipe2,df1)

# r = results.shape[0]
# results.loc[r] = ['Simple Linear Regression','-',rmsesm,rtrsm,'-',rtesm,'-',cv]
# results
# Out:
# Average Price for Test Data: 540333.056
# Intercept: 5780966.031713935
# Coefficient: [-1.67681409e-06 -3.77094193e+04  3.92473270e+04  2.83667860e+02
#   1.01996958e-01  5.07309371e+03  4.40677731e+05  5.63363660e+04
#   2.35598052e+04  1.00217409e+05 -1.03147973e+02 -1.31096939e+02
#  -2.75188327e+03  2.89102574e+01 -4.36243173e+02  5.37001752e+05
#  -1.32603367e+05  1.93970033e+01 -4.69454103e-01]
# cv: 0.692
# root mean square error: 199838.804
# training R2: 0.697
# test R2: 0.706

# %%
# try_cols = ['sqft_living','grade','sqft_above','bathrooms','view','sqft_basement','zipcode','lat','long',
#             'bedrooms','waterfront','floors']
# X = df[try_cols].copy()


X['lon_times_lan'] = X['lat'] * X['long']
X['lon_times_lan_sq'] = X['lon_times_lan']**2
X['lon_times_lan_cubed'] = X['lon_times_lan']**3
X['bedroom_times_bathroom'] = X['bathrooms'] * X['bedrooms']
X['bedroom_times_bathroom_sq'] = X['bedroom_times_bathroom']**2
X['bedroom_times_bathroom_cubed'] = X['bedroom_times_bathroom']**3

X['lat_sq'] = X['lat']**2
X['long_sq'] = X['long']**2
X['lat_cube'] = X['lat']**3
X['long_sq'] = X['long']**3

# # scores = cross_val_score(pipe1, X, y, cv=5, scoring='neg_root_mean_squared_error')
# # print("RMSE:", -scores.mean(), "+/-", scores.std())

# scores = cross_val_score(pipe1, X, y, cv=5, scoring='r2')
# print("R^2:", scores.mean(), "+/-", scores.std())

# %%
df2 = X

# %%
df2['price'] = y.tolist()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21534 entries, 0 to 21596
# Data columns (total 29 columns):
# id                              21534 non-null int64
# bedrooms                        21534 non-null int64
# bathrooms                       21534 non-null float64
# sqft_living                     21534 non-null int64
# sqft_lot                        21534 non-null int64
# floors                          21534 non-null float64
# waterfront                      21534 non-null float64
# view                            21534 non-null float64
# condition                       21534 non-null int64
# grade                           21534 non-null int64
# sqft_above                      21534 non-null int64
# sqft_basement                   21534 non-null float32
# yr_built                        21534 non-null int64
# yr_renovated                    21534 non-null float64
# zipcode                         21534 non-null int64
# lat                             21534 non-null float64
# long                            21534 non-null float64
# sqft_living15                   21534 non-null int64
# sqft_lot15                      21534 non-null int64
# lon_times_lan                   21534 non-null float64
# lon_times_lan_sq                21534 non-null float64
# lon_times_lan_cubed             21534 non-null float64
# bedroom_times_bathroom          21534 non-null float64
# bedroom_times_bathroom_sq       21534 non-null float64
# bedroom_times_bathroom_cubed    21534 non-null float64
# lat_sq                          21534 non-null float64
# long_sq                         21534 non-null float64
# lat_cube                        21534 non-null float64
# price                           21534 non-null float64
# dtypes: float32(1), float64(17), int64(11)
# memory usage: 5.5 MB

# %%
scaler = RobustScaler()
lr = LinearRegression()
pipe3 = make_pipeline(scaler, lr)

pipe3 = model_evaluate(pipe3,df2)

# r = results.shape[0]
# results.loc[r] = ['Simple Linear Regression with Transformation','-',rmsesm,rtrsm,'-',rtesm,'-',cv]
# results
# Out:
# Average Price for Test Data: 540333.056
# Intercept: -510348010359.5075
# Coefficient: [-1.01054732e-06  5.01670017e+04  1.66230578e+05 -1.78755434e+04
#  -2.70745230e-01 -3.40613421e+04  6.54065018e+05  3.80041266e+04
#   3.41477241e+04  7.11924706e+04  1.85855547e+04  1.83855342e+04
#  -8.97318237e+03 -5.42104015e+01 -4.66696722e+03 -5.44304347e+09
#  -2.41367177e+10 -2.49410845e+01 -1.48244486e+00  1.04627615e+09
#   9.27676054e+04  3.64383428e+00 -8.99428476e+04 -5.93882594e+03
#   1.45084139e+02  1.42325482e+09  1.80767632e+05 -1.30754441e+07]
# cv: 0.386
# root mean square error: 446447.34
# training R2: -0.639
# test R2: -0.47
